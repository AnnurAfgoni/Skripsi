# %% [markdown]
# * feature dengan scaling.
# * target tanpa scaling

# %% [markdown]
# ## Library

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential, Model
from keras.layers import concatenate
from keras.layers import Dense, Input, Dropout

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %% [markdown]
# ## Shared Layer Model

# %%
def model(n_input, n_target):
    """
    Fungsi untuk membuat model
    
    arguments:
        n_input = jumlah feature dari data input
        n_outut = jumlah target
        
    return:
        model
    """
    # initializer 
    initializer = tf.keras.initializers.GlorotUniform(seed=None)
    mse = tf.keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
    aktivasi = "relu"

    # input layer
    visible = Input(shape=(n_input))
    
    # branch 1
    x1 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x1 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x1)
    x1 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x1)
    x1 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x1)
    
    # branch 2
    x2 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x2 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x2)
    x2 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x2)
    x2 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x2)
    
    # branch 3
    x3 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x3 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x3)
    x3 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x3)
    x3 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x3)
    
    # branch 4
    x4 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x4 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x4)
    x4 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x4)
    x4 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x4)
    
    # branch 5
    x5 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x5 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x5)
    x5 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x5)
    x5 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x5)
    
    # branch 6
    x6 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x6 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x6)
    x6 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x6)
    x6 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x6)
    
    # branch 7
    x7 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x7 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x7)
    x7 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x7)
    x7 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x7)
    
    # branch 8
    x8 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x8 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x8)
    x8 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x8)
    x8 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x8)
    
    # branch 9
    x9 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x9 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x9)
    x9 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x9)
    x9 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x9)
    
    # branch 10
    x10 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x10 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x10)
    x10 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x10)
    x10 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x10)


    # output
    output = concatenate([x1, x2, x3, x4, x5, x6, x7, x8, x9, x10])

    # model
    model = Model(inputs = visible, 
                  outputs = output)
    
    #compile model
    model.compile(loss = mse,
                  optimizer = 'nadam')
    
    return model

# %% [markdown]
# ## Data

# %%
# input data

feature = pd.read_csv("coef_fourier_kolom.csv")
feature.sample(5)
# Out:
#             c1        c2        c3        c4        c5        c6        c7  \
# 2736 -2.562005 -2.972074 -2.438338 -2.552678 -2.503632 -2.593665 -2.339351
# 1115 -2.563005 -2.973074 -2.445338 -2.559678 -2.549632 -2.639665 -2.610351
# 5386 -2.560005 -2.970074 -2.426338 -2.540678 -2.430632 -2.520665 -1.898351
# 1465 -2.563005 -2.973074 -2.444338 -2.558678 -2.539632 -2.629665 -2.551351
# 2765 -2.562005 -2.972074 -2.438338 -2.552678 -2.503632 -2.593665 -2.335351
#
#             c8        c9       c10  ...       c91       c92     c93       c94  \
# 2736 -1.924729  0.035655  0.002827  ... -2.684741 -2.956202 -2.2496 -2.330488
# 1115 -2.195729 -1.585345 -1.618173  ... -2.685741 -2.957202 -2.2566 -2.337488
# 5386 -1.483729  2.685655  2.652827  ... -2.682741 -2.954202 -2.2376 -2.318488
# 1465 -2.136729 -1.235345 -1.268173  ... -2.685741 -2.957202 -2.2556 -2.336488
# 2765 -1.920729  0.064655  0.031827  ... -2.684741 -2.956202 -2.2496 -2.330488
#
#            c95       c96       c97       c98       c99      c100
# 2736 -2.709364 -2.507247 -1.900158 -1.882519 -0.093523  0.617652
# 1115 -2.755364 -2.553247 -2.171158 -2.153519 -1.714523 -1.003348
# 5386 -2.636364 -2.434247 -1.459158 -1.441519  2.556477  3.267652
# 1465 -2.745364 -2.543247 -2.112158 -2.094519 -1.364523 -0.653348
# 2765 -2.709364 -2.507247 -1.896158 -1.878519 -0.064523  0.646652
#
# [5 rows x 100 columns]

# %%
target = pd.read_csv("coef_ekspansi.csv")
target.sample(5)
# Out:
#             c1        c2        c3        c4        c5        c6        c7  \
# 1162 -0.015813 -0.029548 -0.040681 -0.047727 -0.051312 -0.050883 -0.047206
# 1281  0.015897  0.029810  0.041029  0.048071  0.051554  0.050953  0.047059
# 3500 -0.022184 -0.040169 -0.052051 -0.057467 -0.056129 -0.049084 -0.037717
# 4995 -0.031507 -0.049737 -0.058347 -0.059536 -0.051561 -0.037439 -0.018852
# 1957  0.016702  0.031725  0.043402  0.050332  0.053033  0.051222  0.045835
#
#             c8        c9       c10  ...       c91       c92       c93  \
# 1162 -0.040594 -0.032079 -0.021927  ... -0.027276 -0.051004 -0.070239
# 1281  0.040231  0.031537  0.021300  ...  0.027402  0.051419  0.070788
# 3500 -0.024140 -0.010585  0.000319  ... -0.037813 -0.068434 -0.088623
# 4995  0.000670  0.017713  0.025412  ... -0.053833 -0.084831 -0.099332
# 1957  0.037574  0.027742  0.017043  ...  0.028671  0.054490  0.074560
#
#            c94       c95       c96       c97       c98       c99      c100
# 1162 -0.082394 -0.088556 -0.087820 -0.081502 -0.070139 -0.055469 -0.037861
# 1281  0.082927  0.088909  0.087878  0.081189  0.069460  0.054489  0.036747
# 3500 -0.097825 -0.095559 -0.083585 -0.064220 -0.041032 -0.017836  0.000790
# 4995 -0.101308 -0.087809 -0.063829 -0.032126  0.001358  0.030673  0.043759
# 1957  0.086454  0.091071  0.087970  0.078739  0.064581  0.047698  0.029235
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Data Splitting

# %%
instances_1, feature_dim = feature.shape
instances_2, target_dim = target.shape

# %%
# split training and testing
X_train, X_test, y_train, y_test = train_test_split(feature, target, test_size = 0.2, random_state = 7)

# %% [markdown]
# ## Scaling

# %%
# define scaler
scaler = StandardScaler()

# fit on the training dataset
scaler.fit(X_train)

# scale the training set
X_train = scaler.transform(X_train)

# scale the test dataset
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Training

# %%
# model 

model = model(feature_dim, 10)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  dense (Dense)                  (None, 100)          10100       ['input_1[0][0]']
#
#  dense_4 (Dense)                (None, 100)          10100       ['input_1[0][0]']
#
#  dense_8 (Dense)                (None, 100)          10100       ['input_1[0][0]']
#
#  dense_12 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_16 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_20 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_24 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_28 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_32 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_36 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 75)           7575        ['dense[0][0]']
#
#  dense_5 (Dense)                (None, 75)           7575        ['dense_4[0][0]']
#
#  dense_9 (Dense)                (None, 75)           7575        ['dense_8[0][0]']
#
#  dense_13 (Dense)               (None, 75)           7575        ['dense_12[0][0]']
#
#  dense_17 (Dense)               (None, 75)           7575        ['dense_16[0][0]']
#
#  dense_21 (Dense)               (None, 75)           7575        ['dense_20[0][0]']
#
#  dense_25 (Dense)               (None, 75)           7575        ['dense_24[0][0]']
#
#  dense_29 (Dense)               (None, 75)           7575        ['dense_28[0][0]']
#
#  dense_33 (Dense)               (None, 75)           7575        ['dense_32[0][0]']
#
#  dense_37 (Dense)               (None, 75)           7575        ['dense_36[0][0]']
#
#  dense_2 (Dense)                (None, 50)           3800        ['dense_1[0][0]']
#
#  dense_6 (Dense)                (None, 50)           3800        ['dense_5[0][0]']
#
#  dense_10 (Dense)               (None, 50)           3800        ['dense_9[0][0]']
#
#  dense_14 (Dense)               (None, 50)           3800        ['dense_13[0][0]']
#
#  dense_18 (Dense)               (None, 50)           3800        ['dense_17[0][0]']
#
#  dense_22 (Dense)               (None, 50)           3800        ['dense_21[0][0]']
#
#  dense_26 (Dense)               (None, 50)           3800        ['dense_25[0][0]']
#
#  dense_30 (Dense)               (None, 50)           3800        ['dense_29[0][0]']
#
#  dense_34 (Dense)               (None, 50)           3800        ['dense_33[0][0]']
#
#  dense_38 (Dense)               (None, 50)           3800        ['dense_37[0][0]']
#
#  dense_3 (Dense)                (None, 10)           510         ['dense_2[0][0]']
#
#  dense_7 (Dense)                (None, 10)           510         ['dense_6[0][0]']
#
#  dense_11 (Dense)               (None, 10)           510         ['dense_10[0][0]']
#
#  dense_15 (Dense)               (None, 10)           510         ['dense_14[0][0]']
#
#  dense_19 (Dense)               (None, 10)           510         ['dense_18[0][0]']
#
#  dense_23 (Dense)               (None, 10)           510         ['dense_22[0][0]']
#
#  dense_27 (Dense)               (None, 10)           510         ['dense_26[0][0]']
#
#  dense_31 (Dense)               (None, 10)           510         ['dense_30[0][0]']
#
#  dense_35 (Dense)               (None, 10)           510         ['dense_34[0][0]']
#  dense_39 (Dense)               (None, 10)           510         ['dense_38[0][0]']
#
#  concatenate (Concatenate)      (None, 100)          0           ['dense_3[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_15[0][0]',
#                                                                   'dense_19[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_27[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_35[0][0]',
#                                                                   'dense_39[0][0]']
#
# ==================================================================================================
# Total params: 219,850
# Trainable params: 219,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training 
history = model.fit(
    x = X_train, 
    y = y_train, 
    batch_size = 8, 
    shuffle = True, 
    validation_data = (X_test, y_test), 
    epochs = 250
)
# Out:
# Epoch 1/250
# 540/540 [==============================] - 12s 5ms/step - loss: 0.0097 - val_loss: 0.0082
# Epoch 2/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 3/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0072 - val_loss: 0.0085
# Epoch 4/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 5/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 6/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 7/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 8/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 9/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 10/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 11/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 12/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 13/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0051 - val_loss: 0.0059
# Epoch 14/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 15/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 16/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 17/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 18/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 19/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 20/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 21/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 22/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 23/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 24/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 25/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 26/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 27/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 28/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 29/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 30/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 31/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 32/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 33/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 34/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 35/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 36/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 37/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 38/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 39/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 40/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 41/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 42/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 43/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 44/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 45/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 46/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 47/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 48/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 49/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 50/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 51/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 52/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 53/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 54/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 55/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 56/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 57/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 58/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 59/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 60/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 61/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 62/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 63/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 64/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 65/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 66/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 67/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 68/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 69/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 70/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 71/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 72/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 73/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 74/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 75/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 76/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 77/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 78/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 79/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 80/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 81/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 82/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 83/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 84/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 85/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 86/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 87/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 88/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 89/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 90/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 91/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 92/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 93/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 94/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 95/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 96/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 97/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 98/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 99/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 100/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 101/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 102/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 103/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 104/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 105/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 106/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 107/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 108/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 109/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 110/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 111/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 112/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 113/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 114/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 115/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 116/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 117/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 118/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 119/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 120/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 121/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 122/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 123/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 124/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 125/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 126/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 127/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 128/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 129/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 130/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 131/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 132/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 133/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 134/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 135/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 136/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 137/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 138/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 139/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 140/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 141/250
# 540/540 [==============================] - 2s 4ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 142/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 143/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 144/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 145/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 146/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 147/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 148/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 149/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 150/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 151/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 152/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 153/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 154/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 155/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 156/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 157/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 158/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 159/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 160/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 161/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 162/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 163/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 164/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 165/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 166/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 167/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 168/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 169/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 170/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 171/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 172/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 173/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 174/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 175/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 176/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 177/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 178/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 179/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 180/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 181/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 182/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 183/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 184/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 185/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 186/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 187/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 188/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 189/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 190/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 191/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 192/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 193/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 194/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 195/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 196/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 197/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 198/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 199/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 200/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 201/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 202/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 203/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 204/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 205/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 206/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 207/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 208/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 209/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 210/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 211/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 212/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 213/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 214/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 215/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 216/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 217/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 218/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 219/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 220/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 221/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 222/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 223/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 224/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 225/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 226/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 227/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 228/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 229/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 230/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 231/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 232/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 233/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 234/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 235/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 236/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 237/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 238/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 239/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 240/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 241/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 242/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 243/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 244/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 245/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 246/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 247/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 248/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 249/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 250/250
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0019 - val_loss: 0.0023

# %% [markdown]
# ## Visualisasi

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(loss) + 1)
plt.figure(figsize = (13, 8))
plt.style.use("seaborn")

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %% [markdown]
# ## Prediction

# %%
# prediksi
prediction = model.predict(X_test)
# Out:
# 34/34 [==============================] - 0s 1ms/step

# %%
prediksi = prediction.flatten()
real = y_test.to_numpy().flatten()

# %%
df = {"predict": prediksi, "real": real}
pd.DataFrame(df)
# Out:
#          predict      real
# 0      -0.029283 -0.032400
# 1      -0.046261 -0.050352
# 2      -0.055160 -0.058402
# 3      -0.056713 -0.059045
# 4      -0.049239 -0.050413
# ...          ...       ...
# 107995 -0.087109 -0.087051
# 107996 -0.073150 -0.073553
# 107997 -0.055315 -0.055506
# 107998 -0.035727 -0.035783
# 107999 -0.016217 -0.016780
#
# [108000 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(real, prediksi)
# Out:
# 0.754987469812522

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------
