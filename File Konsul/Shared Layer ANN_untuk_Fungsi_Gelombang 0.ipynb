# %% [markdown]
# * feature tanpa scaling.
# * target tanpa scaling

# %% [markdown]
# ## Library

# %%
# import necessary module

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential, Model
from keras.layers import concatenate
from keras.layers import Dense, Input, Dropout

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %% [markdown]
# ## Shared Layer Model

# %%
def model(n_input, n_target):
    """
    Fungsi untuk membuat model
    
    arguments:
        n_input = jumlah feature dari data input
        n_outut = jumlah target
        
    return:
        model
    """
    # initializer 
    initializer = tf.keras.initializers.GlorotUniform(seed=None)
    mse = tf.keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
    aktivasi = "relu"

    # input layer
    visible = Input(shape=(n_input))
    
    # branch 1
    x1 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x1 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x1)
    x1 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x1)
    x1 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x1)
    
    # branch 2
    x2 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x2 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x2)
    x2 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x2)
    x2 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x2)
    
    # branch 3
    x3 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x3 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x3)
    x3 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x3)
    x3 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x3)
    
    # branch 4
    x4 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x4 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x4)
    x4 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x4)
    x4 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x4)
    
    # branch 5
    x5 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x5 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x5)
    x5 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x5)
    x5 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x5)
    
    # branch 6
    x6 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x6 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x6)
    x6 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x6)
    x6 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x6)
    
    # branch 7
    x7 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x7 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x7)
    x7 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x7)
    x7 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x7)
    
    # branch 8
    x8 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x8 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x8)
    x8 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x8)
    x8 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x8)
    
    # branch 9
    x9 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x9 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x9)
    x9 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x9)
    x9 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x9)
    
    # branch 10
    x10 = Dense(100, kernel_initializer = initializer, activation = aktivasi)(visible)
    x10 = Dense(75, kernel_initializer = initializer, activation = aktivasi)(x10)
    x10 = Dense(50, kernel_initializer = initializer, activation = aktivasi)(x10)
    x10 = Dense(n_target, kernel_initializer = initializer, activation = "tanh")(x10)


    # output
    output = concatenate([x1, x2, x3, x4, x5, x6, x7, x8, x9, x10])

    # model
    model = Model(inputs = visible, 
                  outputs = output)
    
    #compile model
    model.compile(loss = mse,
                  optimizer = 'nadam')
    
    return model

# %% [markdown]
# ## Data

# %%
# input data

feature = pd.read_csv("coef_fourier_kolom.csv")
feature.sample(5)
# Out:
#             c1        c2        c3        c4        c5        c6        c7  \
# 4478 -2.560005 -2.970074 -2.430338 -2.544678 -2.455632 -2.545665 -2.049351
# 4610 -2.560005 -2.970074 -2.429338 -2.543678 -2.451632 -2.541665 -2.027351
# 2246 -2.562005 -2.972074 -2.440338 -2.554678 -2.517632 -2.607665 -2.421351
# 691  -2.564005 -2.974074 -2.447338 -2.561678 -2.560632 -2.650665 -2.680351
# 1131 -2.563005 -2.973074 -2.445338 -2.559678 -2.548632 -2.638665 -2.607351
#
#             c8        c9       c10  ...       c91       c92     c93       c94  \
# 4478 -1.634729  1.777655  1.744827  ... -2.682741 -2.954202 -2.2416 -2.322488
# 4610 -1.612729  1.909655  1.876827  ... -2.682741 -2.954202 -2.2406 -2.321488
# 2246 -2.006729 -0.454345 -0.487173  ... -2.684741 -2.956202 -2.2516 -2.332488
# 691  -2.265729 -2.009345 -2.042173  ... -2.686741 -2.958202 -2.2586 -2.339488
# 1131 -2.192729 -1.569345 -1.602173  ... -2.685741 -2.957202 -2.2566 -2.337488
#
#            c95       c96       c97       c98       c99      c100
# 4478 -2.661364 -2.459247 -1.610158 -1.592519  1.648477  2.359652
# 4610 -2.657364 -2.455247 -1.588158 -1.570519  1.780477  2.491652
# 2246 -2.723364 -2.521247 -1.982158 -1.964519 -0.583523  0.127652
# 691  -2.766364 -2.564247 -2.241158 -2.223519 -2.138523 -1.427348
# 1131 -2.754364 -2.552247 -2.168158 -2.150519 -1.698523 -0.987348
#
# [5 rows x 100 columns]

# %%
target = pd.read_csv("coef_ekspansi.csv")
target.sample(10)
# Out:
#             c1        c2        c3        c4        c5        c6        c7  \
# 2447 -0.017762 -0.033699 -0.045641 -0.052346 -0.054188 -0.051164 -0.044334
# 1221  0.015853  0.029676  0.040852  0.047896  0.051432  0.050918  0.047134
# 1653  0.016263  0.030764  0.042244  0.049245  0.052345  0.051135  0.046479
# 4941 -0.031233 -0.049535 -0.058307 -0.059658 -0.051881 -0.037946 -0.019532
# 5262 -0.032736 -0.050565 -0.058389 -0.058819 -0.049939 -0.034991 -0.015653
# 5255 -0.032704 -0.050543 -0.058389 -0.058841 -0.049988 -0.035065 -0.015749
# 4006  0.025399  0.044030  0.055241  0.059451  0.055864  0.046241  0.032122
# 5056  0.031805  0.049950  0.058379  0.059390  0.051195  0.036868  0.018092
# 3931  0.024899  0.043466  0.054810  0.059224  0.055988  0.046756  0.033047
# 4953 -0.031293 -0.049581 -0.058317 -0.059632 -0.051811 -0.037833 -0.019381
#
#             c8        c9       c10  ...       c91       c92       c93  \
# 2447 -0.034743 -0.023920 -0.012952  ... -0.030407 -0.057708 -0.078161
# 1221  0.040417  0.031813  0.021620  ...  0.027336  0.051206  0.070508
# 1653  0.038912  0.029621  0.019123  ...  0.027969  0.052942  0.072712
# 4941 -0.000149  0.016824  0.024675  ... -0.053351 -0.084467 -0.099245
# 5262  0.004450  0.021773  0.028722  ... -0.056011 -0.086355 -0.099518
# 5255  0.004340  0.021658  0.028631  ... -0.055954 -0.086316 -0.099515
# 4006  0.016222  0.001208 -0.009022  ...  0.043275  0.074937  0.093921
# 5056 -0.001576 -0.018692 -0.026217  ...  0.054360  0.085218  0.099410
# 3931  0.017489  0.002683 -0.007681  ...  0.042421  0.073981  0.093201
# 4953  0.000033  0.017022  0.024839  ... -0.053458 -0.084549 -0.099266
#
#            c94       c95       c96       c97       c98       c99      c100
# 2447 -0.089632 -0.092770 -0.087602 -0.075922 -0.059512 -0.040956 -0.022092
# 1221  0.082656  0.088731  0.087851  0.081350  0.069807  0.054989  0.037315
# 1653  0.084754  0.090065  0.087989  0.080003  0.067020  0.051045  0.032894
# 4941 -0.101496 -0.088336 -0.064675 -0.033275 -0.000038  0.029146  0.042492
# 5262 -0.100197 -0.085151 -0.059743 -0.026720  0.007815  0.037658  0.049468
# 5255 -0.100232 -0.085231 -0.059867 -0.026882  0.007627  0.037461  0.049312
# 4006  0.101051  0.094986  0.078656  0.054620  0.027453  0.001743 -0.015688
# 5056  0.101081  0.087207  0.062875  0.030842 -0.002906 -0.032356 -0.045146
# 3931  0.100678  0.095206  0.079537  0.056198  0.029619  0.004270 -0.013393
# 4953 -0.101456 -0.088220 -0.064488 -0.033019  0.000273  0.029486  0.042775
#
# [10 rows x 100 columns]

# %% [markdown]
# ## Data Splitting

# %%
instances_1, feature_dim = feature.shape
instances_2, target_dim = target.shape

# %%
# split training and testing
X_train, X_test, y_train, y_test = train_test_split(feature, target, test_size = 0.2, random_state = 7)

# %% [markdown]
# ## Training

# %%
# model 

model = model(feature_dim, 10)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  dense (Dense)                  (None, 100)          10100       ['input_1[0][0]']
#
#  dense_4 (Dense)                (None, 100)          10100       ['input_1[0][0]']
#
#  dense_8 (Dense)                (None, 100)          10100       ['input_1[0][0]']
#
#  dense_12 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_16 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_20 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_24 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_28 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_32 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_36 (Dense)               (None, 100)          10100       ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 75)           7575        ['dense[0][0]']
#
#  dense_5 (Dense)                (None, 75)           7575        ['dense_4[0][0]']
#
#  dense_9 (Dense)                (None, 75)           7575        ['dense_8[0][0]']
#
#  dense_13 (Dense)               (None, 75)           7575        ['dense_12[0][0]']
#
#  dense_17 (Dense)               (None, 75)           7575        ['dense_16[0][0]']
#
#  dense_21 (Dense)               (None, 75)           7575        ['dense_20[0][0]']
#
#  dense_25 (Dense)               (None, 75)           7575        ['dense_24[0][0]']
#
#  dense_29 (Dense)               (None, 75)           7575        ['dense_28[0][0]']
#
#  dense_33 (Dense)               (None, 75)           7575        ['dense_32[0][0]']
#
#  dense_37 (Dense)               (None, 75)           7575        ['dense_36[0][0]']
#
#  dense_2 (Dense)                (None, 50)           3800        ['dense_1[0][0]']
#
#  dense_6 (Dense)                (None, 50)           3800        ['dense_5[0][0]']
#
#  dense_10 (Dense)               (None, 50)           3800        ['dense_9[0][0]']
#
#  dense_14 (Dense)               (None, 50)           3800        ['dense_13[0][0]']
#
#  dense_18 (Dense)               (None, 50)           3800        ['dense_17[0][0]']
#
#  dense_22 (Dense)               (None, 50)           3800        ['dense_21[0][0]']
#
#  dense_26 (Dense)               (None, 50)           3800        ['dense_25[0][0]']
#
#  dense_30 (Dense)               (None, 50)           3800        ['dense_29[0][0]']
#
#  dense_34 (Dense)               (None, 50)           3800        ['dense_33[0][0]']
#
#  dense_38 (Dense)               (None, 50)           3800        ['dense_37[0][0]']
#
#  dense_3 (Dense)                (None, 10)           510         ['dense_2[0][0]']
#
#  dense_7 (Dense)                (None, 10)           510         ['dense_6[0][0]']
#
#  dense_11 (Dense)               (None, 10)           510         ['dense_10[0][0]']
#
#  dense_15 (Dense)               (None, 10)           510         ['dense_14[0][0]']
#
#  dense_19 (Dense)               (None, 10)           510         ['dense_18[0][0]']
#
#  dense_23 (Dense)               (None, 10)           510         ['dense_22[0][0]']
#
#  dense_27 (Dense)               (None, 10)           510         ['dense_26[0][0]']
#
#  dense_31 (Dense)               (None, 10)           510         ['dense_30[0][0]']
#
#  dense_35 (Dense)               (None, 10)           510         ['dense_34[0][0]']
#  dense_39 (Dense)               (None, 10)           510         ['dense_38[0][0]']
#
#  concatenate (Concatenate)      (None, 100)          0           ['dense_3[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_15[0][0]',
#                                                                   'dense_19[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_27[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_35[0][0]',
#                                                                   'dense_39[0][0]']
#
# ==================================================================================================
# Total params: 219,850
# Trainable params: 219,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training 
history = model.fit(x = X_train, 
           y = y_train, 
           batch_size = 8, 
           shuffle = True, 
           validation_data = (X_test, y_test), 
           epochs = 250)
# Out:
# Epoch 1/250
# 540/540 [==============================] - 32s 10ms/step - loss: 0.0134 - val_loss: 0.0091
# Epoch 2/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 3/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 4/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 5/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0080 - val_loss: 0.0080
# Epoch 6/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0078 - val_loss: 0.0081
# Epoch 7/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 8/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 9/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 10/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0076 - val_loss: 0.0084
# Epoch 11/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 12/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 13/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 14/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0076 - val_loss: 0.0079
# Epoch 15/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 16/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 17/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 18/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 19/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0073 - val_loss: 0.0076
# Epoch 20/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 21/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 22/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 23/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 24/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 25/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0071 - val_loss: 0.0078
# Epoch 26/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 27/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 28/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 29/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 30/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 31/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 32/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0068 - val_loss: 0.0068
# Epoch 33/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 34/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 35/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 36/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 37/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 38/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 39/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 40/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 41/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 42/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 43/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 44/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 45/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 46/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 47/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 48/250
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 49/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 50/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 51/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 52/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 53/250
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 54/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 55/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 56/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 57/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 58/250
# 540/540 [==============================] - 5s 8ms/step - loss: 0.0065 - val_loss: 0.0068
# Epoch 59/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 60/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 61/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 62/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 63/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 64/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 65/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 66/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 67/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 68/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 69/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 70/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 71/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 72/250
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 73/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 74/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 75/250
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 76/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 77/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 78/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 79/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 80/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 81/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 82/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 83/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0065
# Epoch 84/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 85/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 86/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 87/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 88/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 89/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 90/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 91/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 92/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 93/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 94/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 95/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 96/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 97/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 98/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 99/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 100/250
# 540/540 [==============================] - 5s 10ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 101/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 102/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 103/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 104/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 105/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 106/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0065
# Epoch 107/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 108/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 109/250
# 540/540 [==============================] - 5s 9ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 110/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 111/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 112/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 113/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 114/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 115/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 116/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 117/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 118/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 119/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 120/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 121/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 122/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 123/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 124/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 125/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 126/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 127/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 128/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 129/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 130/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 131/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 132/250
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 133/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 134/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 135/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 136/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 137/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 138/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 139/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 140/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 141/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 142/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 143/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 144/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 145/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 146/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 147/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 148/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 149/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 150/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 151/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 152/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 153/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 154/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 155/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 156/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 157/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 158/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 159/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 160/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 161/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 162/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 163/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 164/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 165/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 166/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 167/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 168/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 169/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 170/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 171/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 172/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 173/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 174/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 175/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 176/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 177/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 178/250
# 540/540 [==============================] - 4s 6ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 179/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 180/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 181/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0064
# Epoch 182/250
# 540/540 [==============================] - 3s 5ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 183/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 184/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 185/250
# 540/540 [==============================] - 4s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 186/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 187/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 188/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 189/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 190/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 191/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 192/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 193/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 194/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 195/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 196/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 197/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 198/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 199/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 200/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 201/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 202/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 203/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 204/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 205/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 206/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 207/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 208/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 209/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 210/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 211/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 212/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
# Epoch 213/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 214/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 215/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 216/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 217/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 218/250
# 540/540 [==============================] - 4s 6ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 219/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 220/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 221/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 222/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 223/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 224/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 225/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 226/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 227/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 228/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 229/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 230/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 231/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 232/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 233/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 234/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 235/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 236/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 237/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 238/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 239/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 240/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 241/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 242/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 243/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 244/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 245/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 246/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 247/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 248/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 249/250
# 540/540 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 250/250
# 540/540 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0064

# %% [markdown]
# ## Visualisasi

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(loss) + 1)
plt.figure(figsize = (13, 8))
plt.style.use("seaborn")

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %% [markdown]
# ## Prediction

# %%
# prediksi
prediction = model.predict(X_test)
# Out:
# 34/34 [==============================] - 2s 4ms/step

# %%
prediksi = prediction.flatten()
real = y_test.to_numpy().flatten()

# %%
df = {"predict": prediksi, "real": real}
pd.DataFrame(df)
# Out:
#          predict      real
# 0       0.005145 -0.032400
# 1       0.007883 -0.050352
# 2       0.009969 -0.058402
# 3       0.011273 -0.059045
# 4       0.011820 -0.050413
# ...          ...       ...
# 107995 -0.003932 -0.087051
# 107996 -0.003400 -0.073553
# 107997 -0.002623 -0.055506
# 107998 -0.001816 -0.035783
# 107999 -0.000986 -0.016780
#
# [108000 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(real, prediksi)
# Out:
# 0.31203033391329704

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------
